# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# train: weights='', cfg=models/yolov5s.yaml, data=Reconocimiento_jp-6/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=180, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolov5s_reconocimiento_version_aumentada, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-312-g1bcd17ee Python-3.8.19 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# ...

# %%
# !python detect.py --weights yolov5s.pt --conf 0.25 --source 0
# display.Image(filename='runs/detect/exp/zidane.jpg', width=600)
# Out:
# ^C

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="TIibHlElOYN91RtS8O21")
project = rf.workspace("juanprogramator").project("reconocimiento_jp")
version = project.version(8)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Reconocimiento_jp-8 in yolov5pytorch:: 100%|██████████| 1954/1954 [00:03<00:00, 588.51it/s]

# %%
# !python train.py --img 640 --batch 32 --epochs 180 --data Reconocimiento_jp-8/data.yaml --cfg models/yolov5s.yaml --weights '' --name yolov5s_reconocimiento_version3_aumentada
# Out:
# train: weights='', cfg=models/yolov5s.yaml, data=Reconocimiento_jp-8/data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=180, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, evolve_population=data\hyps, resume_evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=yolov5s_reconocimiento_version3_aumentada, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest, ndjson_console=False, ndjson_file=False
# github: up to date with https://github.com/ultralytics/yolov5
# YOLOv5  v7.0-312-g1bcd17ee Python-3.8.19 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# ...

# %%
# !python detect.py --weights runs/train/yolov5s_reconocimiento_version2_aumentada/weights/best.pt --source Reconocimiento_jp-8/valid/images --img-size 640 --conf 0.4 --save-txt --save-conf
# Out:
# detect: weights=['runs/train/yolov5s_reconocimiento_version3_aumentada/weights/best.pt'], source=Reconocimiento_jp-8/valid/images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_csv=False, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  v7.0-312-g1bcd17ee Python-3.8.19 torch-2.2.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/146 C:\Users\Juano\Desktop\proyecto_yolov5\yolov5\Reconocimiento_jp-8\valid\images\104_jpg.rf.8336ffc75d03343ad3189605b0abf1cc.jpg: 640x640 1 Persona_desconocida, 6.0ms
# ...

# %%
# !python detect.py --weights runs/train/yolov5s_reconocimiento_version2_aumentada/weights/best.pt --img 640 --conf 0.25 --source 1
